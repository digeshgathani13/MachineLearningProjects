# %%
import nltk

# %%
path='D://SimpliLearn Projects//Machine Learning//Demo Datasets//Lesson 11//'
with open(path+'wiki_corpus.txt', 'r') as myfile:
    data = myfile.read().replace('\n', '')

# %%
data2 = data.replace('/', '')

# %%
for i, line in enumerate(data2.split('\n')):
    if i>10:
        break
    print(str(i) + ':' + line)
# Out:
# 0:Apple Inc. is an American multinational technology company headquartered in Cupertino, California, that designs, develops, and sells consumer electronics, computer software, and online services. The company's hardware products include the iPhone smartphone, the iPad tablet computer, the Mac personal computer, the iPod portable media player, the Apple Watch smartwatch, the Apple TV digital media player, and the HomePod smart speaker. Apple's software includes the macOS and iOS operating systems, the iTunes media player, the Safari web browser, and the iLife and iWork creativity and productivity suites, as well as professional applications like Final Cut Pro, Logic Pro, and Xcode. Its online services include the iTunes Store, the iOS App Store and Mac App Store, Apple Music, and iCloud.Apple was founded by Steve Jobs, Steve Wozniak, and Ronald Wayne in April 1976 to develop and sell Wozniak's Apple I personal computer. It was incorporated as Apple Computer, Inc., in January 1977, and
# ...

# %%
from nltk import sent_tokenize, word_tokenize

# %%
sent_tokenize(data2)
# Out:
# ['Apple Inc. is an American multinational technology company headquartered in Cupertino, California, that designs, develops, and sells consumer electronics, computer software, and online services.',
#  "The company's hardware products include the iPhone smartphone, the iPad tablet computer, the Mac personal computer, the iPod portable media player, the Apple Watch smartwatch, the Apple TV digital media player, and the HomePod smart speaker.",
#  "Apple's software includes the macOS and iOS operating systems, the iTunes media player, the Safari web browser, and the iLife and iWork creativity and productivity suites, as well as professional applications like Final Cut Pro, Logic Pro, and Xcode.",
#  "Its online services include the iTunes Store, the iOS App Store and Mac App Store, Apple Music, and iCloud.Apple was founded by Steve Jobs, Steve Wozniak, and Ronald Wayne in April 1976 to develop and sell Wozniak's Apple I personal computer.",
# ...

# %%
for sent in sent_tokenize(data2):
    print(word_tokenize(sent))
# Out:
# ['Apple', 'Inc.', 'is', 'an', 'American', 'multinational', 'technology', 'company', 'headquartered', 'in', 'Cupertino', ',', 'California', ',', 'that', 'designs', ',', 'develops', ',', 'and', 'sells', 'consumer', 'electronics', ',', 'computer', 'software', ',', 'and', 'online', 'services', '.']
# ['The', 'company', "'s", 'hardware', 'products', 'include', 'the', 'iPhone', 'smartphone', ',', 'the', 'iPad', 'tablet', 'computer', ',', 'the', 'Mac', 'personal', 'computer', ',', 'the', 'iPod', 'portable', 'media', 'player', ',', 'the', 'Apple', 'Watch', 'smartwatch', ',', 'the', 'Apple', 'TV', 'digital', 'media', 'player', ',', 'and', 'the', 'HomePod', 'smart', 'speaker', '.']
# ...

# %%
from nltk.corpus import stopwords
stopwords_en = stopwords.words('english')

# %%
single_token = list(map(str.lower, word_tokenize(data2)))
print(single_token)
# Out:
# ['apple', 'inc.', 'is', 'an', 'american', 'multinational', 'technology', 'company', 'headquartered', 'in', 'cupertino', ',', 'california', ',', 'that', 'designs', ',', 'develops', ',', 'and', 'sells', 'consumer', 'electronics', ',', 'computer', 'software', ',', 'and', 'online', 'services', '.', 'the', 'company', "'s", 'hardware', 'products', 'include', 'the', 'iphone', 'smartphone', ',', 'the', 'ipad', 'tablet', 'computer', ',', 'the', 'mac', 'personal', 'computer', ',', 'the', 'ipod', 'portable', 'media', 'player', ',', 'the', 'apple', 'watch', 'smartwatch', ',', 'the', 'apple', 'tv', 'digital', 'media', 'player', ',', 'and', 'the', 'homepod', 'smart', 'speaker', '.', 'apple', "'s", 'software', 'includes', 'the', 'macos', 'and', 'ios', 'operating', 'systems', ',', 'the', 'itunes', 'media', 'player', ',', 'the', 'safari', 'web', 'browser', ',', 'and', 'the', 'ilife', 'and', 'iwork', 'creativity', 'and', 'productivity', 'suites', ',', 'as', 'well', 'as', 'professional', 'applications'
# ...

# %%
stopwords_en = set(stopwords.words('english'))
print([word for word in single_token if word not in stopwords_en])
# Out:
# ['apple', 'inc.', 'american', 'multinational', 'technology', 'company', 'headquartered', 'cupertino', ',', 'california', ',', 'designs', ',', 'develops', ',', 'sells', 'consumer', 'electronics', ',', 'computer', 'software', ',', 'online', 'services', '.', 'company', "'s", 'hardware', 'products', 'include', 'iphone', 'smartphone', ',', 'ipad', 'tablet', 'computer', ',', 'mac', 'personal', 'computer', ',', 'ipod', 'portable', 'media', 'player', ',', 'apple', 'watch', 'smartwatch', ',', 'apple', 'tv', 'digital', 'media', 'player', ',', 'homepod', 'smart', 'speaker', '.', 'apple', "'s", 'software', 'includes', 'macos', 'ios', 'operating', 'systems', ',', 'itunes', 'media', 'player', ',', 'safari', 'web', 'browser', ',', 'ilife', 'iwork', 'creativity', 'productivity', 'suites', ',', 'well', 'professional', 'applications', 'like', 'final', 'cut', 'pro', ',', 'logic', 'pro', ',', 'xcode', '.', 'online', 'services', 'include', 'itunes', 'store', ',', 'ios', 'app', 'store', 'mac', 'app', 'sto
# ...

# %%
from string import punctuation
print('from string.punctuation:-', type(punctuation), punctuation)
# Out:
# from string.punctuation:- <class 'str'> !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
stopwords_en_withpunct = stopwords_en.union(set(punctuation))
print(stopwords_en_withpunct)
# Out:
# {'by', 'has', 'we', 'doesn', '=', 'then', 've', "haven't", 'than', ':', 'don', 'before', '^', "you'd", 'below', 'mustn', 'who', 'haven', 'themselves', 'are', 'what', 'any', "mightn't", 'yours', 'yourselves', 'mightn', 'further', "'", '"', 'through', 'at', 'd', "you've", 'does', 'if', 'hadn', '$', 'wasn', 'he', 'most', 'only', 'am', 'had', "you'll", 'him', 'y', 'your', '`', 'ourselves', 'whom', 'i', 'myself', 'will', '+', 'needn', 'once', 'all', 'with', 'should', 'but', 'after', "didn't", 'about', 'to', '|', "should've", 'be', 'nor', 'same', '(', 'it', 'own', "wasn't", 'an', 'yourself', 'there', 'as', "mustn't", 'above', 'weren', '>', 'which', 'off', 'me', ')', "needn't", 'from', "couldn't", 'you', 'wouldn', 'and', 'other', 'again', "she's", 'were', '\\', 'out', 'been', 'she', 'itself', "doesn't", '[', 'in', 'now', 'herself', '*', 'until', 'a', 'too', 'each', 'ain', 'over', '&', '_', 'against', 'himself', 'ours', 'them', '/', 't', 'shan', "wouldn't", '!', 'hers', 'down', "weren't", 'b
# ...

# %%
print([word for word in single_token if word not in stopwords_en_withpunct])
# Out:
# ['apple', 'inc.', 'american', 'multinational', 'technology', 'company', 'headquartered', 'cupertino', 'california', 'designs', 'develops', 'sells', 'consumer', 'electronics', 'computer', 'software', 'online', 'services', 'company', "'s", 'hardware', 'products', 'include', 'iphone', 'smartphone', 'ipad', 'tablet', 'computer', 'mac', 'personal', 'computer', 'ipod', 'portable', 'media', 'player', 'apple', 'watch', 'smartwatch', 'apple', 'tv', 'digital', 'media', 'player', 'homepod', 'smart', 'speaker', 'apple', "'s", 'software', 'includes', 'macos', 'ios', 'operating', 'systems', 'itunes', 'media', 'player', 'safari', 'web', 'browser', 'ilife', 'iwork', 'creativity', 'productivity', 'suites', 'well', 'professional', 'applications', 'like', 'final', 'cut', 'pro', 'logic', 'pro', 'xcode', 'online', 'services', 'include', 'itunes', 'store', 'ios', 'app', 'store', 'mac', 'app', 'store', 'apple', 'music', 'icloud.apple', 'founded', 'steve', 'jobs', 'steve', 'wozniak', 'ronald', 'wayne', 'apr
# ...

# %%
from nltk.stem import PorterStemmer
porter = PorterStemmer()

for word in single_token:
    print(porter.stem(word))
# Out:
# appl
# inc.
# is
# an
# american
# multin
# technolog
# compani
# headquart
# in
# cupertino
# ,
# california
# ,
# that
# design
# ,
# develop
# ,
# and
# sell
# consum
# electron
# ,
# comput
# softwar
# ,
# and
# onlin
# servic
# .
# the
# compani
# 's
# hardwar
# product
# includ
# the
# iphon
# smartphon
# ,
# the
# ipad
# tablet
# comput
# ,
# the
# mac
# person
# comput
# ,
# the
# ipod
# portabl
# media
# player
# ,
# the
# appl
# watch
# smartwatch
# ,
# the
# appl
# tv
# digit
# media
# player
# ,
# and
# the
# homepod
# smart
# speaker
# .
# appl
# 's
# softwar
# includ
# the
# maco
# and
# io
# oper
# system
# ,
# the
# itun
# media
# player
# ,
# the
# safari
# web
# browser
# ,
# and
# the
# ilif
# and
# iwork
# creativ
# and
# product
# suit
# ,
# as
# well
# as
# profession
# applic
# like
# final
# cut
# pro
# ,
# logic
# pro
# ,
# and
# xcode
# .
# it
# onlin
# servic
# includ
# the
# itun
# store
# ,
# the
# io
# app
# store
# and
# mac
# app
# store
# ,
# appl
# ...

# %%
from nltk.stem import WordNetLemmatizer
wnl = WordNetLemmatizer()

# %%
for word in single_token:
    print(wnl.lemmatize(word))
# Out:
# apple
# inc.
# is
# an
# american
# multinational
# technology
# company
# headquartered
# in
# cupertino
# ,
# california
# ,
# that
# design
# ,
# develops
# ,
# and
# sell
# consumer
# electronics
# ,
# computer
# software
# ,
# and
# online
# service
# .
# the
# company
# 's
# hardware
# product
# include
# the
# iphone
# smartphone
# ,
# the
# ipad
# tablet
# computer
# ,
# the
# mac
# personal
# computer
# ,
# the
# ipod
# portable
# medium
# player
# ,
# the
# apple
# watch
# smartwatch
# ,
# the
# apple
# tv
# digital
# medium
# player
# ,
# and
# the
# homepod
# smart
# speaker
# .
# apple
# 's
# software
# includes
# the
# macos
# and
# io
# operating
# system
# ,
# the
# itunes
# medium
# player
# ,
# the
# safari
# web
# browser
# ,
# and
# the
# ilife
# and
# iwork
# creativity
# and
# productivity
# suite
# ,
# a
# well
# a
# professional
# application
# like
# final
# cut
# pro
# ,
# logic
# pro
# ,
# and
# xcode
# .
# it
# online
# service
# include
# the
# itunes
# ...

# %%
stop_words = set(stopwords.words('english'))
tokenized = sent_tokenize(data2)
for i in tokenized:
    wordslist = nltk.word_tokenize(i)
    wordslist = [w for w in wordslist if not w in stop_words]
    tagged = nltk.pos_tag(wordslist)
    
    print(tagged)
# Out:
# [('Apple', 'NNP'), ('Inc.', 'NNP'), ('American', 'NNP'), ('multinational', 'NNP'), ('technology', 'NN'), ('company', 'NN'), ('headquartered', 'VBD'), ('Cupertino', 'NNP'), (',', ','), ('California', 'NNP'), (',', ','), ('designs', 'NNS'), (',', ','), ('develops', 'NNS'), (',', ','), ('sells', 'VBZ'), ('consumer', 'NN'), ('electronics', 'NNS'), (',', ','), ('computer', 'NN'), ('software', 'NN'), (',', ','), ('online', 'NN'), ('services', 'NNS'), ('.', '.')]
# ...

# %%
sentences = nltk.sent_tokenize(data2)
tokenized_sentences = [nltk.word_tokenize(sentence) for sentence in sentences]
tagged_sentences = [nltk.pos_tag(sentence) for sentence in tokenized_sentences]
chunked_sentences = nltk.ne_chunk_sents(tagged_sentences, binary=True)

def extract_entity_names(t):
    entity_names = []
    
    if hasattr(t, 'label') and t.label:
        if t.label() == 'NE':
            entity_names.append(' '.join([child[0] for child in t]))
        else:
            for child in t:
                entity_names.extend(extract_entity_names(child))
    return entity_names

entity_names = []
for tree in chunked_sentences:
    entity_names.extend(extract_entity_names(tree))
    
print(set(entity_names))
# Out:
# {'iLife', 'Steve Jobs', 'Ronald Wayne', 'NeXT', 'iOS App Store', 'Apple Music', 'CEO Gil Amelio', 'US', 'California', 'Apple Computer', 'Jobs', 'Steve Wozniak', 'Tim Cook', 'Cupertino', 'iTunes', 'American', 'HomePod', 'Safari', 'Wozniak', 'iWork', 'Apple II', 'Microsoft', 'Mac App Store', 'iPhone', 'Logic Pro', 'Apple Watch', 'iPad', 'Huawei', 'Mac', 'iOS', 'iPod', 'Samsung', 'Final Cut Pro', 'U.S.', 'Apple Inc.', 'CEO', 'Xcode', 'iTunes Store', 'macOS', 'Apple'}
